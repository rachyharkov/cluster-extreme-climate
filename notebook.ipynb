# %%
import pandas as pd
import numpy as np

column_name = ['nama_stasiun', 'rr', 'tgl_pengamatan_ch', 'tx','tgl_pengamatan_tx','tn','tgl_pengamatan_tn','tAvg','tgl_pengamatan_tAvg','rh','tgl_pengamatan_rh','wx','tgl_pengamatan_wx']
dataset = pd.read_csv('extreme-climate-dataset.csv', sep=';', header=None, skiprows=1, names=column_name)

dataset
# Out:
#                                           nama_stasiun     rr  \
# 0    Balai Besar Meteorologi Klimatologi dan Geofis...  130.9
# 1                             Pos Meteorologi Penggung  148.0
# 2                  Pos Meteorologi Tampa Padang Mamuju  118.0
# 3                         Pos Pengamatan Kahang-Kahang  124.0
# 4                            Stasiun Geofisika Bandung  160.0
# ..                                                 ...    ...
# 165             Stasiun Meteorologi Wamena Jaya Wijaya   82.4
# 166                     Stasiun Meteorologi Yogyakarta   71.3
# 167                 Stasiun Meteorologi Yuvai Semaring   97.7
# 168         Stasiun Meteorologi Zainuddin Abdul Madjid  127.0
# 169  Stasiun Pemantau Atmosfer Global Bukit Koto Ta...   47.0
#
#     tgl_pengamatan_ch    tx tgl_pengamatan_tx    tn tgl_pengamatan_tn  tAvg  \
# 0          11/05/2020  37.0        14/10/2021  17.6        15/07/2022  31.6
# 1          14/01/2020  37.0        14/10/2020  21.0        27/07/2020  31.5
# 2          10/05/2022   NaN               NaN   NaN               NaN   NaN
# 3          18/01/2021  33.6        19/11/2020  19.2        26/07/2021  27.9
# 4          02/05/2020  32.4        23/08/2020  15.6        27/07/2021  28.9
# ..                ...   ...               ...   ...               ...   ...
# 165        17/02/2022  30.4        18/05/2020   9.4        30/06/2022  22.8
# 166        27/05/2022  32.9        11/05/2022  17.8        26/07/2022  29.5
# 167        20/05/2021   NaN               NaN  14.2        08/06/2022  25.3
# 168        29/05/2020  36.9        10/02/2022  16.6        25/07/2022  29.2
# 169        23/08/2020  29.4        12/08/2020  15.2        02/12/2020  23.7
#
#     tgl_pengamatan_tAvg    rh tgl_pengamatan_rh  wx tgl_pengamatan_wx
# 0            13/01/2020  56.0        13/01/2020   1        28/06/2020
# 1            30/09/2020  51.0        12/09/2020   2        06/04/2020
# 2                   NaN   NaN               NaN   2        27/05/2022
# 3            07/04/2022   NaN               NaN   3        09/04/2020
# 4            04/10/2020  46.0        04/10/2020   1        24/04/2020
# ..                  ...   ...               ...  ..               ...
# 165          05/05/2021  64.0        03/11/2021   2        23/01/2020
# 166          05/05/2022  70.0        25/07/2022   2        03/06/2022
# 167          08/05/2020  71.0        14/10/2021   1        01/01/2020
# 168          14/11/2020  70.0        20/08/2022   1        02/04/2021
# 169          20/08/2020  83.0        24/08/2020   2        06/08/2020
#
# [170 rows x 13 columns]

# %% [markdown]
# ## Preprocessing

# %%
dataset.dtypes
# Out:
# nama_stasiun            object
# rr                     float64
# tgl_pengamatan_ch       object
# tx                     float64
# tgl_pengamatan_tx       object
# tn                     float64
# tgl_pengamatan_tn       object
# tAvg                   float64
# tgl_pengamatan_tAvg     object
# rh                     float64
# tgl_pengamatan_rh       object
# wx                       int64
# tgl_pengamatan_wx       object
# dtype: object

# %%
dataset.drop(['tgl_pengamatan_ch', 'tgl_pengamatan_tx','tgl_pengamatan_tn','tgl_pengamatan_tAvg','tgl_pengamatan_rh','tgl_pengamatan_wx'], axis=1, inplace=True)
dataset
# Out:
#                                           nama_stasiun     rr    tx    tn  \
# 0    Balai Besar Meteorologi Klimatologi dan Geofis...  130.9  37.0  17.6
# 1                             Pos Meteorologi Penggung  148.0  37.0  21.0
# 2                  Pos Meteorologi Tampa Padang Mamuju  118.0   NaN   NaN
# 3                         Pos Pengamatan Kahang-Kahang  124.0  33.6  19.2
# 4                            Stasiun Geofisika Bandung  160.0  32.4  15.6
# ..                                                 ...    ...   ...   ...
# 165             Stasiun Meteorologi Wamena Jaya Wijaya   82.4  30.4   9.4
# 166                     Stasiun Meteorologi Yogyakarta   71.3  32.9  17.8
# 167                 Stasiun Meteorologi Yuvai Semaring   97.7   NaN  14.2
# 168         Stasiun Meteorologi Zainuddin Abdul Madjid  127.0  36.9  16.6
# 169  Stasiun Pemantau Atmosfer Global Bukit Koto Ta...   47.0  29.4  15.2
#
#      tAvg    rh  wx
# 0    31.6  56.0   1
# 1    31.5  51.0   2
# 2     NaN   NaN   2
# 3    27.9   NaN   3
# 4    28.9  46.0   1
# ..    ...   ...  ..
# 165  22.8  64.0   2
# 166  29.5  70.0   2
# 167  25.3  71.0   1
# 168  29.2  70.0   1
# 169  23.7  83.0   2
#
# [170 rows x 7 columns]

# %%
dataset.describe()
# Out:
#                rr           tx          tn        tAvg          rh          wx
# count  170.000000   165.000000  169.000000  161.000000  160.000000  170.000000
# mean   158.651765   582.739394   19.357396   29.782609   65.331250    1.594118
# std     56.857275  2268.813278    2.434613    1.811545    7.584096    0.570446
# min     47.000000    27.200000    9.400000   21.500000   38.000000    1.000000
# 25%    118.525000    34.800000   18.800000   29.500000   60.000000    1.000000
# 50%    149.300000    35.500000   20.000000   30.000000   67.000000    2.000000
# 75%    188.700000    36.800000   21.000000   30.600000   70.250000    2.000000
# max    420.000000  9999.000000   23.000000   33.600000   83.000000    3.000000

# %% [markdown]
# - 8888: data tidak terukur
# - 9999: Tidak Ada Data (tidak dilakukan pengukuran)

# %%
# delete row with 8888 value
dataset.drop(dataset[dataset['tx'] == 8888].index, inplace=True)
dataset.drop(dataset[dataset['tx'] == 9999].index, inplace=True)
dataset
# Out:
#                                           nama_stasiun     rr    tx    tn  \
# 0    Balai Besar Meteorologi Klimatologi dan Geofis...  130.9  37.0  17.6
# 1                             Pos Meteorologi Penggung  148.0  37.0  21.0
# 2                  Pos Meteorologi Tampa Padang Mamuju  118.0   NaN   NaN
# 3                         Pos Pengamatan Kahang-Kahang  124.0  33.6  19.2
# 4                            Stasiun Geofisika Bandung  160.0  32.4  15.6
# ..                                                 ...    ...   ...   ...
# 165             Stasiun Meteorologi Wamena Jaya Wijaya   82.4  30.4   9.4
# 166                     Stasiun Meteorologi Yogyakarta   71.3  32.9  17.8
# 167                 Stasiun Meteorologi Yuvai Semaring   97.7   NaN  14.2
# 168         Stasiun Meteorologi Zainuddin Abdul Madjid  127.0  36.9  16.6
# 169  Stasiun Pemantau Atmosfer Global Bukit Koto Ta...   47.0  29.4  15.2
#
#      tAvg    rh  wx
# 0    31.6  56.0   1
# 1    31.5  51.0   2
# 2     NaN   NaN   2
# 3    27.9   NaN   3
# 4    28.9  46.0   1
# ..    ...   ...  ..
# 165  22.8  64.0   2
# 166  29.5  70.0   2
# 167  25.3  71.0   1
# 168  29.2  70.0   1
# 169  23.7  83.0   2
#
# [161 rows x 7 columns]

# %%
# preprocessing
dataset = dataset.dropna()
dataset
# Out:
#                                           nama_stasiun     rr    tx    tn  \
# 0    Balai Besar Meteorologi Klimatologi dan Geofis...  130.9  37.0  17.6
# 1                             Pos Meteorologi Penggung  148.0  37.0  21.0
# 4                            Stasiun Geofisika Bandung  160.0  32.4  15.6
# 5                       Stasiun Geofisika Banjarnegara  135.0  31.2  13.4
# 9                          Stasiun Geofisika Kepahiang  125.4  32.4  16.2
# ..                                                 ...    ...   ...   ...
# 164                         Stasiun Meteorologi Utarom  156.1  36.9  21.8
# 165             Stasiun Meteorologi Wamena Jaya Wijaya   82.4  30.4   9.4
# 166                     Stasiun Meteorologi Yogyakarta   71.3  32.9  17.8
# 168         Stasiun Meteorologi Zainuddin Abdul Madjid  127.0  36.9  16.6
# 169  Stasiun Pemantau Atmosfer Global Bukit Koto Ta...   47.0  29.4  15.2
#
#      tAvg    rh  wx
# 0    31.6  56.0   1
# 1    31.5  51.0   2
# 4    28.9  46.0   1
# 5    23.2  75.0   1
# 9    26.3  71.0   1
# ..    ...   ...  ..
# 164  32.2  65.0   2
# 165  22.8  64.0   2
# 166  29.5  70.0   2
# 168  29.2  70.0   1
# 169  23.7  83.0   2
#
# [149 rows x 7 columns]

# %%
# find coordinate

import json
from urllib import request

arr_link_request = [
    'https://gis.bmkg.go.id/arcgis/rest/services/Distribusi_Stasiun/MapServer/0/query?text=Meteorologi&f=json',
    'https://gis.bmkg.go.id/arcgis/rest/services/Distribusi_Stasiun/MapServer/1/query?text=Klimatologi&f=json',
    'https://gis.bmkg.go.id/arcgis/rest/services/Distribusi_Stasiun/MapServer/2/query?text=Geofisika&f=json',
    'https://gis.bmkg.go.id/arcgis/rest/services/Distribusi_Stasiun/MapServer/3/query?text=Stasiun&f=json',
    'https://gis.bmkg.go.id/arcgis/rest/services/Distribusi_Stasiun/MapServer/4/query?text=Balai+Besar&f=json',
]

list_of_allstasiun = []

for link in arr_link_request:
    with request.urlopen(link) as url:
        data = json.loads(url.read().decode())
        for stasiun in data['features']:
            list_of_allstasiun.append(stasiun['attributes'])
            list_of_allstasiun[-1]['x'] = stasiun['geometry']['x']
            list_of_allstasiun[-1]['y'] = stasiun['geometry']['y']

df_allstasiun = pd.DataFrame(list_of_allstasiun)
column_stasiun = ['nama_stasiun', 'longitude', 'latitude']
# change df_allstasiun column name to column_stasiun
df_allstasiun.columns = column_stasiun
df_allstasiun
# Out:
#                                           nama_stasiun  longitude  latitude
# 0             Stasiun Meteorologi Sultan Iskandar Muda   95.41700   5.52244
# 1                     Stasiun Meteorologi Malikussaleh   96.94749   5.22869
# 2        Stasiun Meteorologi Cut Nyak Dhien Nagan Raya   96.24796   4.04928
# 3                     Stasiun Meteorologi Maimun Saleh   95.33785   5.87655
# 4                        Stasiun Meteorologi FL Tobing   98.88000   1.55000
# ..                                                 ...        ...       ...
# 187  Balai Besar Meteorologi Klimatologi dan Geofis...   98.64000   3.53970
# 188  Balai Besar Meteorologi Klimatologi dan Geofis...  106.75636  -6.30253
# 189  Balai Besar Meteorologi Klimatologi  dan Geofi...  115.17860  -8.73810
# 190  Balai Besar Meteorologi Klimatologi dan Geofis...  140.68624  -2.57522
# 191  Balai Besar Meteorologi Klimatologi dan Geofis...  119.45227  -5.14283
#
# [192 rows x 3 columns]

# %%
for index, row in dataset.iterrows():
    for index2, row2 in df_allstasiun.iterrows():
        if row['nama_stasiun'] == row2['nama_stasiun']:
            dataset.at[index, 'longitude'] = row2['longitude']
            dataset.at[index, 'latitude'] = row2['latitude']

dataset
# Out:
# C:\Users\akuradz\AppData\Local\Temp\ipykernel_6220\9591067.py:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.at[index, 'longitude'] = row2['longitude']
# C:\Users\akuradz\AppData\Local\Temp\ipykernel_6220\9591067.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   dataset.at[index, 'latitude'] = row2['latitude']
#                                           nama_stasiun     rr    tx    tn  \
# 0    Balai Besar Meteorologi Klimatologi dan Geofis...  130.9  37.0  17.6
# 1                             Pos Meteorologi Penggung  148.0  37.0  21.0
# 4                            Stasiun Geofisika Bandung  160.0  32.4  15.6
# 5                       Stasiun Geofisika Banjarnegara  135.0  31.2  13.4
# 9                          Stasiun Geofisika Kepahiang  125.4  32.4  16.2
# ..                                                 ...    ...   ...   ...
# 164                         Stasiun Meteorologi Utarom  156.1  36.9  21.8
# 165             Stasiun Meteorologi Wamena Jaya Wijaya   82.4  30.4   9.4
# 166                     Stasiun Meteorologi Yogyakarta   71.3  32.9  17.8
# 168         Stasiun Meteorologi Zainuddin Abdul Madjid  127.0  36.9  16.6
# 169  Stasiun Pemantau Atmosfer Global Bukit Koto Ta...   47.0  29.4  15.2
#
#      tAvg    rh  wx  longitude  latitude
# 0    31.6  56.0   1   98.64000   3.53970
# 1    31.5  51.0   2  108.53904  -6.75530
# 4    28.9  46.0   1  107.59733  -6.88356
# 5    23.2  75.0   1  109.70690  -7.33300
# 9    26.3  71.0   1  102.58900  -3.55000
# ..    ...   ...  ..        ...       ...
# 164  32.2  65.0   2  133.75000  -3.67000
# 165  22.8  64.0   2  138.94639  -4.08861
# 166  29.5  70.0   2  110.05448  -7.90746
# 168  29.2  70.0   1  116.24982  -8.75277
# 169  23.7  83.0   2  100.38230  -0.25050
#
# [149 rows x 9 columns]

# %%
# drop row with nan value
dataset = dataset.dropna()
dataset
# Out:
#                                           nama_stasiun     rr    tx    tn  \
# 0    Balai Besar Meteorologi Klimatologi dan Geofis...  130.9  37.0  17.6
# 1                             Pos Meteorologi Penggung  148.0  37.0  21.0
# 4                            Stasiun Geofisika Bandung  160.0  32.4  15.6
# 5                       Stasiun Geofisika Banjarnegara  135.0  31.2  13.4
# 9                          Stasiun Geofisika Kepahiang  125.4  32.4  16.2
# ..                                                 ...    ...   ...   ...
# 164                         Stasiun Meteorologi Utarom  156.1  36.9  21.8
# 165             Stasiun Meteorologi Wamena Jaya Wijaya   82.4  30.4   9.4
# 166                     Stasiun Meteorologi Yogyakarta   71.3  32.9  17.8
# 168         Stasiun Meteorologi Zainuddin Abdul Madjid  127.0  36.9  16.6
# 169  Stasiun Pemantau Atmosfer Global Bukit Koto Ta...   47.0  29.4  15.2
#
#      tAvg    rh  wx  longitude  latitude
# 0    31.6  56.0   1   98.64000   3.53970
# 1    31.5  51.0   2  108.53904  -6.75530
# 4    28.9  46.0   1  107.59733  -6.88356
# 5    23.2  75.0   1  109.70690  -7.33300
# 9    26.3  71.0   1  102.58900  -3.55000
# ..    ...   ...  ..        ...       ...
# 164  32.2  65.0   2  133.75000  -3.67000
# 165  22.8  64.0   2  138.94639  -4.08861
# 166  29.5  70.0   2  110.05448  -7.90746
# 168  29.2  70.0   1  116.24982  -8.75277
# 169  23.7  83.0   2  100.38230  -0.25050
#
# [123 rows x 9 columns]

# %%
# world map
import folium
from folium.plugins import HeatMap

# create map
m = folium.Map(location=[-2.5, 118], zoom_start=5)

weight = dataset['rr'].tolist() / dataset['rr'].max()
lat = dataset['latitude'].tolist()
lon = dataset['longitude'].tolist()

# add heatmap
HeatMap(
    list(
        zip(lat, lon, weight)
    ), 
    radius=10,
    max_zoom=13,
    min_opacity=0.5,
    max_val=1,
    blur=10,
    gradient={0.2: 'blue', 0.4: 'lime', 0.6: 'orange', 1: 'red'}
    ).add_to(m)

# show map
m
# Out:
# C:\Users\akuradz\AppData\Local\Temp\ipykernel_6220\1597900726.py:13: UserWarning: The `max_val` parameter is no longer necessary. The largest intensity is calculated automatically.
#   HeatMap(
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_660b4ee89452b0a8c312d3c7b7c7412e {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_660b4ee89452b0a8c312d3c7b7c7412e&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_660b4ee89452b0a8c312d3c7b7c7412e = L.map(
#                 &quot;map_660b4ee89452b0a8c312d3c7b7c7412e&quot;,
#                 {
#                     center: [-2.5, 118.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_d447946dddaf41ac16eeb36b34ccecd6 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_660b4ee89452b0a8c312d3c7b7c7412e);
#
#
#             var heat_map_ec95ed78e47b38234034a0aae6102452 = L.heatLayer(
#                 [[3.539699999999982, 98.63999999999999, 0.40030581039755353], [-6.755299999999977, 108.53904, 0.4525993883792049], [-6.883559999999989, 107.59733, 0.4892966360856269], [-7.333000000000027, 109.70690000000002, 0.41284403669724773], [-3.5500000000000114, 102.589, 0.3834862385321101], [-4.836310000000026, 104.87, 0.33211009174311923], [1.443399999999997, 124.83889999999997, 0.4256880733944954], [-7.734860000000026, 111.76682, 0.4892966360856269], [-7.704560000000015, 112.63532999999995, 0.4522935779816514], [-7.819999999999993, 110.30000000000001, 0.3363914373088685], [-6.100000000000023, 106.38, 0.36330275229357795], [-3.8652000000000157, 102.31189999999998, 0.8256880733944955], [-2.5923099999999977, 140.16791999999998, 0.762691131498471], [1.5500000000000114, 99.44999999999999, 0.3819571865443425], [-6.976830000000007, 110.37779999999998, 0.5229357798165137], [-3.346400000000017, 128.9284, 1.0], [-2.554719999999975, 120.32421999999997, 0.46788990825688076], [-4.523379999999975, 129.90430000000003, 0.572782874617737], [-8.214999999999975, 114.35530000000006, 0.38868501529051985], [-0.5600000000000023, 114.52999999999997, 0.4235474006116208], [-5.470000000000027, 122.62, 0.35015290519877673], [1.1648999999999887, 97.7036, 0.41590214067278286], [-6.286699999999996, 106.56389000000001, 0.36269113149847093], [-6.699999999999989, 106.85000000000002, 0.37920489296636084], [4.04928000000001, 96.24795999999998, 0.7232415902140673], [-10.766619999999989, 123.07394999999997, 0.36452599388379203], [-2.170000000000016, 106.13, 0.35932721712538224], [-2.083000000000027, 101.44999999999999, 0.19908256880733943], [0.6385000000000218, 122.85249999999996, 0.6455657492354739], [-2.5299999999999727, 140.72000000000003, 0.4966360856269113], [-0.8911800000000198, 131.28575, 0.43088685015290523], [-10.1678, 123.67039, 0.9348623853211009], [-2.0500000000000114, 126.0, 0.4253822629969419], [-3.926879999999983, 136.38, 0.2837920489296636], [-3.8582000000000107, 102.33670000000001, 0.7871559633027522], [1.5500000000000114, 98.88, 0.626605504587156], [-1.1906900000000178, 136.10361, 0.2929663608562691], [-8.629999999999995, 120.45000000000005, 0.4318042813455657], [-8.63576999999998, 122.23752000000002, 0.3669724770642202], [1.8409199999999828, 127.79049999999995, 0.9113149847094801], [-8.275199999999984, 122.99860000000001, 0.5266055045871559], [-3.3000000000000114, 116.16999999999996, 0.4614678899082569], [-2.5500000000000114, 112.92999999999995, 0.5406727828746177], [1.1166699999999992, 104.11667, 0.5874617737003058], [-2.730000000000018, 111.66000000000003, 0.4214067278287462], [-0.3299999999999841, 102.32, 0.42996941896024465], [-7.384599999999978, 112.78330000000005, 0.390519877675841], [3.329999999999984, 117.57000000000005, 0.39877675840978594], [-5.663700000000006, 132.73620000000005, 0.3617737003058104], [-1.4203800000000228, 120.65701000000001, 0.3119266055045872], [-6.155590000000018, 106.83999999999997, 0.8486238532110092], [-6.734399999999994, 108.26299999999998, 0.655045871559633], [-8.486730000000023, 119.88683000000003, 0.24281345565749238], [3.6457300000000146, 98.88488000000001, 0.40519877675840976], [5.876550000000009, 95.33785, 0.3284403669724771], [-3.550740000000019, 118.98054000000002, 0.5137614678899083], [-8.134709999999984, 124.59000000000003, 0.25810397553516823], [5.228689999999972, 96.94749000000002, 0.5051987767584097], [-1.8500000000000227, 138.75, 0.4617737003058104], [-3.7905299999999897, 128.10074999999995, 0.6116207951070336], [3.7882399999999734, 98.71492, 0.48623853211009177], [1.4431000000000154, 125.17970000000003, 0.6009174311926605], [-3.970100000000002, 122.58950000000004, 0.2868501529051988], [-5.472100000000012, 105.32100000000003, 0.3525993883792049], [-5.113749999999982, 119.41983000000005, 0.6691131498470948], [-0.029999999999972715, 109.33999999999997, 0.5137614678899083], [-6.111850000000004, 106.11000000000001, 0.5516819571865443], [-6.948599999999999, 110.41989999999998, 0.474006116207951 ...

# %%
# k-means clustering

from sklearn.cluster import KMeans

# select feature
X = dataset[['rr', 'tAvg', 'rh', 'wx']].values

# standardize data
from sklearn.preprocessing import MinMaxScaler
scaler = MinMaxScaler()
X_scaled = scaler.fit_transform(X)

# find optimal k
wcss = []
for i in range(1, 11):
    kmeans = KMeans(n_clusters=i, init='k-means++', random_state=42)
    kmeans.fit(X_scaled)
    wcss.append(kmeans.inertia_)

import matplotlib.pyplot as plt
plt.plot(range(1, 11), wcss)
plt.title('The Elbow Method')
plt.xlabel('Number of clusters')
plt.ylabel('WCSS')
plt.show()

# %%
# k-means clustering
kmeans = KMeans(n_clusters=2, random_state=42)
y_kmeans = kmeans.fit_predict(X_scaled)

# create map
peta_persebaran = folium.Map(location=[-2.5, 118], zoom_start=5)

color = ['red', 'green']

# add cluster
for i in range(0, len(y_kmeans)):
    clusterny = y_kmeans[i]
    folium.CircleMarker(
        location=[lat[i], lon[i]],
        radius=13,
        color=color[clusterny],
        fill=True,
        fill_color=color[clusterny],
        fill_opacity=0.7,
        popup='Cluster ' + str(y_kmeans[i]) + ' ' + str(dataset['nama_stasiun'].iloc[i])
    ).add_to(peta_persebaran)

# show map
peta_persebaran
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;head&gt;
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-1.12.4.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/js/bootstrap.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.6.0/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/bootstrap/3.2.0/css/bootstrap-theme.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://maxcdn.bootstrapcdn.com/font-awesome/4.6.3/css/font-awesome.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_39285ae9bc3b6ac3e73d76f0ee586701 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#             &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_39285ae9bc3b6ac3e73d76f0ee586701&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#             var map_39285ae9bc3b6ac3e73d76f0ee586701 = L.map(
#                 &quot;map_39285ae9bc3b6ac3e73d76f0ee586701&quot;,
#                 {
#                     center: [-2.5, 118.0],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 5,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_b753275bca77492f949d444006540098 = L.tileLayer(
#                 &quot;https://{s}.tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;Data by \u0026copy; \u003ca href=\&quot;http://openstreetmap.org\&quot;\u003eOpenStreetMap\u003c/a\u003e, under \u003ca href=\&quot;http://www.openstreetmap.org/copyright\&quot;\u003eODbL\u003c/a\u003e.&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 18, &quot;maxZoom&quot;: 18, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             ).addTo(map_39285ae9bc3b6ac3e73d76f0ee586701);
#
#
#             var circle_marker_76602584ef20e0977cb3429097fcc5b4 = L.circleMarker(
#                 [3.539699999999982, 98.63999999999999],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_39285ae9bc3b6ac3e73d76f0ee586701);
#
#
#         var popup_bfeb30bc207e342494d7533a572b9440 = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_c71964bcb3e7b64f1e943f1733dc1d73 = $(`&lt;div id=&quot;html_c71964bcb3e7b64f1e943f1733dc1d73&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 1 Balai Besar Meteorologi Klimatologi dan Geofisika Wilayah I&lt;/div&gt;`)[0];
#                 popup_bfeb30bc207e342494d7533a572b9440.setContent(html_c71964bcb3e7b64f1e943f1733dc1d73);
#
#
#
#         circle_marker_76602584ef20e0977cb3429097fcc5b4.bindPopup(popup_bfeb30bc207e342494d7533a572b9440)
#         ;
#
#
#
#
#             var circle_marker_5360f43b0c312d43b04d529a177c2a84 = L.circleMarker(
#                 [-6.755299999999977, 108.53904],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;green&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;green&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_39285ae9bc3b6ac3e73d76f0ee586701);
#
#
#         var popup_400189cee8c74d06484e6fb2601e35df = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_56d8e4fc9ee244755418e58428f502c8 = $(`&lt;div id=&quot;html_56d8e4fc9ee244755418e58428f502c8&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 0 Pos Meteorologi Penggung&lt;/div&gt;`)[0];
#                 popup_400189cee8c74d06484e6fb2601e35df.setContent(html_56d8e4fc9ee244755418e58428f502c8);
#
#
#
#         circle_marker_5360f43b0c312d43b04d529a177c2a84.bindPopup(popup_400189cee8c74d06484e6fb2601e35df)
#         ;
#
#
#
#
#             var circle_marker_770eceb8f04a2612e4997ebebae8caff = L.circleMarker(
#                 [-6.883559999999989, 107.59733],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;red&quot;, &quot;fillOpacity&quot;: 0.7, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 13, &quot;stroke&quot;: true, &quot;weight&quot;: 3}
#             ).addTo(map_39285ae9bc3b6ac3e73d76f0ee586701);
#
#
#         var popup_97e2ed02179ec962bbe1e04d52e06f4c = L.popup({&quot;maxWidth&quot;: &quot;100%&quot;});
#
#
#
#                 var html_17c565b17389feb908eea0dd771a5eed = $(`&lt;div id=&quot;html_17c565b17389feb908eea0dd771a5eed&quot; style=&quot;width: 100.0%; height: 100.0%;&quot;&gt;Cluster 1 Stasiun Geofisika Bandung&lt;/div&gt;`)[0];
#                 popup_97e2ed02179ec962bbe1e04d52e06f4c.setContent(html_17c565b17389feb908eea0dd771a5eed);
#
#
#
#         circle_marker_770eceb8f04a2612e4997ebebae8caff.bindPopup(popup_97e2ed02179ec962bbe1e04d52e06f4c)
#         ;
#
#
#
#
#             var circle_marker_ab65b4e20532138f94c949005af654c4 = L.circleMarker(
#                 [-7.333000000000027, 109.70690000000002],
#                 {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;red&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true

# %%
# classify = ['TINGGI', 'SEDANG', 'RENDAH']
# dataset_classified = dataset.copy()
# dataset_classified['rr_level'] = pd.cut(dataset['rr'], bins=3, labels=classify)
# dataset_classified['tx_level'] = pd.cut(dataset['tx'], bins=3, labels=classify)
# dataset_classified['tn_level'] = pd.cut(dataset['tn'], bins=3, labels=classify)
# dataset_classified['tAvg_level'] = pd.cut(dataset['tAvg'], bins=3, labels=classify)
# dataset_classified['rh_level'] = pd.cut(dataset['rh'], bins=3, labels=classify)
# dataset_classified['wx_level'] = pd.cut(dataset['wx'], bins=3, labels=classify)
# dataset_classified.drop(['rr', 'tx', 'tn', 'tAvg', 'rh', 'wx'], axis=1, inplace=True)
# dataset_classified

# %% [markdown]
# Keterangan :
# - 8888: data tidak terukur
# - 9999: Tidak Ada Data (tidak dilakukan pengukuran)
# - Tn: Temperatur minimum	 (°C)
# - Tx: Temperatur maksimum (°C)
# - Tavg: Temperatur rata-rata (°C)
# - RH_avg: Kelembapan rata-rata (%)
# - RR: Curah hujan (mm)
# - ss: Lamanya penyinaran matahari (jam)
# - ff_x: Kecepatan angin maksimum (m/s)
# - ddd_x: Arah angin saat kecepatan maksimum (°)
# - ff_avg: Kecepatan angin rata-rata (m/s)
# - ddd_car: Arah angin terbanyak (°)
